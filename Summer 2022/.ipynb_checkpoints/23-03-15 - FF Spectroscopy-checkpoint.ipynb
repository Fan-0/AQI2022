# %%
import cirq
import qutip as qt
import scipy.signal as si
import scipy.linalg as la
from mezze.tfq import *
import pickle as pk
import random
from matplotlib import pyplot as plt
from tqdm import tqdm
import pickle
import numpy as np
def loadData(inp):
    # for reading also binary mode is important
    dbfile = open(inp, 'rb')     
    db = pickle.load(dbfile)
    dbfile.close()
    return db

# %%
# System parameters
N = 128
dt = 1
T = N*dt
dw = 2*np.pi/T #sampling rate)
Nw = 8192
ww = np.linspace(0,np.pi,Nw)

# %%
# Useful filter function calculator
def FF(control):
    Theta = np.cumsum(control)*dt
    ff = np.abs(np.fft.rfft( np.cos(Theta), 2*Nw-1)*dt)**2 + np.abs(np.fft.rfft( np.sin(Theta), 2*Nw-1)*dt)**2
    return ff/N**2

# %%
test = loadData('FGRAFS_controls/x_gate_sampling.p')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 test = loadData('FGRAFS_controls/x_gate_sampling.p')
#
# Input In [29], in loadData(inp)
#      12 def loadData(inp):
#      13     # for reading also binary mode is important
# ---> 14     dbfile = open(inp, 'rb')
#      15     db = pickle.load(dbfile)
#      16     dbfile.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'FGRAFS_controls/x_gate_sampling.p'

# %% [markdown]
# ### Controls

# %%
# Center frequency of FF
wH = dw*10
controls = wH*np.ones(N)

# Amplitude shifting to get a π pulse
delta_w = (np.pi - wH*T + (wH*T - np.sum(controls)*dt % (2*np.pi)) )/T
controls *= (delta_w+wH)/wH

# Compute control power
power = np.sum(controls**2)*dt
print(power)
# Out:
# 34.00387141312819

# %%
zero_state = [1,0]
one_state = [0,1]

U_n = qt.identity(2).full()
for n,Omega_n in enumerate(controls):
    H_n = qt.sigmax().full()*Omega_n/2
    U_n = la.expm(-1j*dt*H_n) @ U_n
final_state = U_n@zero_state

gate_fidelity = np.abs(final_state.transpose().conj() @ one_state)**2
print("Ideal gate fidelity: %.8f"%gate_fidelity)
plt.plot(np.arange(N), (controls), color='k')
# Out:
# Ideal gate fidelity: 1.00000000

# %% [markdown]
# ## Bandpass noise

# %%
# Compute arma coefficients for narrow band noise with center wc 
def arma_coefficients(wc):
    b = si.firwin(128, .001)
    b *= np.cos(wc*np.arange(len(b)))
    b = b/np.linalg.norm(b)*.1
    return b

# %%
# center frequencies of injected PSD
center_freqs = np.linspace(0, .5*np.pi, 100)
print(center_freqs)
plt.figure(figsize=(6,3), dpi=150)

for wc in center_freqs[::4]:
    b = arma_coefficients(wc)
    S = SimpleDephasingSchWARMAFier(b, [1,])
    plt.plot(*S.psd(worN=Nw))
    
plt.plot(ww, FF(controls), color='k')
plt.ylabel('$S(\omega)$', fontsize=14)
plt.xlabel('$\omega$', fontsize=14)
plt.show()
# Out:
# [0.         0.01586663 0.03173326 0.04759989 0.06346652 0.07933315
#  0.09519978 0.11106641 0.12693304 0.14279967 0.1586663  0.17453293
#  0.19039955 0.20626618 0.22213281 0.23799944 0.25386607 0.2697327
#  0.28559933 0.30146596 0.31733259 0.33319922 0.34906585 0.36493248
#  0.38079911 0.39666574 0.41253237 0.428399   0.44426563 0.46013226
#  0.47599889 0.49186552 0.50773215 0.52359878 0.53946541 0.55533203
#  0.57119866 0.58706529 0.60293192 0.61879855 0.63466518 0.65053181
#  0.66639844 0.68226507 0.6981317  0.71399833 0.72986496 0.74573159
#  0.76159822 0.77746485 0.79333148 0.80919811 0.82506474 0.84093137
#  0.856798   0.87266463 0.88853126 0.90439789 0.92026451 0.93613114
#  0.95199777 0.9678644  0.98373103 0.99959766 1.01546429 1.03133092
#  1.04719755 1.06306418 1.07893081 1.09479744 1.11066407 1.1265307
#  1.14239733 1.15826396 1.17413059 1.18999722 1.20586385 1.22173048
#  1.23759711 1.25346374 1.26933037 1.28519699 1.30106362 1.31693025
#  1.33279688 1.34866351 1.36453014 1.38039677 1.3962634  1.41213003
#  1.42799666 1.44386329 1.45972992 1.47559655 1.49146318 1.50732981
#  1.52319644 1.53906307 1.5549297  1.57079633]

# %% [markdown]
# ### Noise trajectories

# %%
# Generate dummy circuit to get noise trajectories from schwarma
dummy_circ = cirq.Circuit([cirq.I(cirq.GridQubit(1,1))]*N)

# %%
# Generate sample trajectories
b = arma_coefficients(center_freqs[0])
S = SimpleDephasingSchWARMAFier(b, [1,])
noise_trajectories = S.gen_noise_instances(dummy_circ,100) # 1000 different trajectories

# %%
plt.figure(figsize=(6,3))
plt.plot(noise_trajectories[:10].T,'-o')
plt.ylabel('Rotation Angle', size=14)
plt.xlabel(r'Gate #', size=14)
plt.title(r'Some Time-Correlated $Z$-rotations')
plt.show()

# %% [markdown]
# ## Simulations scanning over different center frequencies

# %%
fidelity_wc = {}

# Scan over frequencies by varying noise center frequency
num_trajs = 10 # Change to 100 for better resolution
for wc in tqdm(center_freqs):
    b = arma_coefficients(wc)
    S = SimpleDephasingSchWARMAFier(b, [1,])
    noise_trajectories = S.gen_noise_instances(dummy_circ, num_trajs)
    
    noisy_fidelities = []
    # Average over noise trajectories
    for beta in noise_trajectories:
        beta *= np.sqrt(0.05*power/np.sum(beta**2)/T) # Rescale for reasonable power

        U_n = qt.identity(2).full()
        for n,Omega_n in enumerate(controls):
            H_n = qt.sigmax().full()*Omega_n/2
            U_n = la.expm(-1j*qt.sigmaz().full()*beta[n]) @ la.expm(-1j*dt*H_n) @ U_n
        final_state = U_n@zero_state
        
        noisy_fidelities += [np.abs(final_state.transpose().conj() @ one_state)**2]
        
    fidelity_wc[wc] = np.mean(noisy_fidelities)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [01:44<00:00,  1.04s/it]

# %%
plt.figure(dpi=150, figsize=(4,3))

infidelity = 1-np.array(list(fidelity_wc.values()))
filter_function = FF(controls)

plt.plot(ww, filter_function*np.max(infidelity)/np.max(filter_function), label=r'$F(\omega)\propto \delta(\omega-\omega_H)$')
plt.plot(center_freqs, infidelity, label=r'$I(T)\approx \int d\omega S_{\omega_c}(\omega) F(\omega)$')
plt.ylabel('$I(T), F(\omega)$',size=16)
plt.xlabel('$\omega$',size=16)
plt.legend(frameon=False)

plt.tight_layout()
plt.show()
