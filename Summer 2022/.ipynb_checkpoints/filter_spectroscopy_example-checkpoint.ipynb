# %% [markdown]
# # Filter Function Spectroscopy

# %% [markdown]
# Here we show how to use injected noise to extract information about the filter function (or frequency response) of a quantum system when subject to controlled evolution. As an illustrative example, we will focus on the CPMG dynamical decoupling sequence, as the filter function is well understood.

# %% [markdown]
# ## Broad Overview of the Theory

# %% [markdown]
# Consider the case of a single qubit system subject to a Hamiltonian $H(t)=H_C(t)+H_S(t)$, where $H_C(t)$ describes the control Hamiltonian and $H_S(t)$ denotes what we will call the signal Hamiltonian. The control Hamiltonian can be thought of as the control operations (or gates) that are implemented in a circuit, while the signal Hamiltonian can be thought of as the noise (or signal) we inject into the circuit. With the Hamiltonian defined, consider the following experiment: prepare the qubit in the state $|\psi(0)\rangle=U_{prep}|0\rangle$, allow it to evolve according to $U(t)=\mathcal{T}_{+}e^{-i\int^{t}_{0} H(s) ds}$, and measure the state $|\psi(0)\rangle$. One can now ask the question: what is the probability of the qubit remaining in the initially prepared state? The answer is determined by calculating the survival probability
#
# $$
# F(t)=|\langle \psi(0)|U(T)|\psi(0)\rangle|^2 = |\langle 0|U^\dagger_{prep} U(t) U_{prep}|0\rangle|^2.
# $$
#
# Interestingly, without going into the math in detail, the survival probability can be approximated by the expression $F(t)\approx\frac{1}{2}(1+e^{-\chi(t)})$, where
#
# $$
# \chi(t) = \sum_\alpha \int^{\infty}_0 \frac{d\omega}{2\pi} F_\alpha(\omega,t) S_\alpha(\omega)
# $$
#
# is referred to as the decay function. In general, the decay function can be a sum of terms called overlap integrals, where each integral is a convolution between a filter function $F_\alpha(\omega,t)$ and the power spectral density (PSD) $S_\alpha(\omega)$. The PSD may represent many things, e.g., fluctuating noise processes or, in our case, an injected signal.
#
# So, what can we do with the above expressions? It turns out that they can be used in many ways to study the noisy dynamics of a system, estimate noise PSDs when they are not well-understood (e.g., on hardware), or estimate a filter function. Obviously, the last application is most interesting to us. We are particularly interested in using the overlap integral to estimate the filter function of an F-GRAFS control waveform. We expect the control to tailor the filter function such that it possesses spectral nulls at particular locations in frequency space. Given a particular control sequence, we can use engineered $S_\alpha(\omega)$ to vary the overlap between the injected signal and $F(\omega,t)$. If the overlap is large, then the decay function will be larger; thus, resulting in a lower survival probability.
#
# For simplicity, assume that we only have a single $S_\alpha(\omega)=S(\omega)$. In order to "map" out the filter function $F(\omega,t)$, we will use narrow band noise such that $S(\omega)\approx A\delta(\omega-\omega_0)$. Plugging this into the decay function, we obtain
#
# $$
# \chi(t) \approx \frac{1}{2\pi} F(\omega_0,t).
# $$
#
# This result is the driving force for filter spectroscopy. Namely, narrow band noise may be used to isolate filter function contributions to the decay function at particular frequencies. By varying $\omega_0$ over some range and examining the decay function (or survival probability), we gain indirect knowledge of the filter function.

# %% [markdown]
# # CPMG Filter Function Spectroscopy

# %%
import numpy as np
import scipy.signal as si
import scipy.linalg as la
import matplotlib.pyplot as plt
import qiskit as qk
from qiskit import Aer

# %% [markdown]
# ## Build a Circuit

# %% [markdown]
# First, let's build a circuit representation of CPMG using qiskit.

# %%
def cpmg(N, M):
    # N: Number of repetitions (cycles)
    # M: Number of identity gates for interpulse delay
    circ = qk.QuantumCircuit(1,1)
    for iN  in range(N):
        [circ.i(0) for _ in range(M)]
        circ.x(0)
        [circ.i(0) for _ in range(2*M)]
        circ.x(0)
        [circ.i(0) for _ in range(M)]
    return circ

# %%
def cpmg_experiment(N,M):
    circ = qk.QuantumCircuit(1,1)
    circ.rx(np.pi/2,0)
    circ.compose(cpmg(5,3), inplace=True)
    circ.rx(-np.pi/2,0)
    circ.measure(0,0)
    return circ

noiseless_circ = cpmg_experiment(2,5)
noiseless_circ.draw('mpl')

# %% [markdown]
# ## Noise Specifications

# %% [markdown]
# We will need to take circuits like those above and inject noise into them. In particular, we want the noise to be very narrow band so that we may probe the filter function as specific, localized frequencies.

# %%
s_pow = 1e-3
a = [1,]
NN = 512
BW = 0.001 # changes narrowness of noise spectrum
w0 = 0.2 # changes center frequency
b = si.firwin(NN, BW)*np.cos(w0*np.pi*np.arange(NN))
#b = b/la.norm(b)*np.sqrt(s_pow)
w, h = si.freqz(b, a)

fig = plt.figure(dpi=70)
ax = fig.add_subplot(111)
ax.plot(w, b)
ax.set_ylabel('power')
ax.set_xlabel('normalized frequency')
# Out:
# Text(0.5, 0, 'normalized frequency')

# %% [markdown]
# To map out the filter function, we will vary the center frequency of the noise. An example of this is given below.

# %%
fig = plt.figure(dpi=70)
ax = fig.add_subplot(111)    
    
s_pow = 1e-3
a = [1,]
NN = 128
BW = 0.01 # changes narrowness of noise spectrum
for w0 in np.linspace(0.02,0.98,50):
    b = si.firwin(NN, BW)*np.cos(w0*np.pi*np.arange(NN))
    b = b/la.norm(b)*np.sqrt(s_pow)
    w, h = si.freqz(b, a)    
    ax.plot(w, abs(h)**2)
ax.set_ylabel('power')
ax.set_xlabel('normalized frequency')
# Out:
# Text(0.5, 0, 'normalized frequency')

# %% [markdown]
# ## Circuit with Noise Injection

# %% [markdown]
# Now, let's create a circuit where we inject dephasing noise (noise along $\sigma_z$ or the $z$-axis of the single qubit Bloch sphere) after every gate.

# %%
def noisy_cpmg_experiment(N, M):
    # N: Number of repetitions (cycles)
    # M: Number of identity gates for interpulse delay
    
    tot_num_gates = N*(2 + 4*M) + 2
    x = qk.circuit.ParameterVector('x', length=tot_num_gates)
    
    circ = qk.QuantumCircuit(1,1)
    circ.rx(np.pi/2, 0)
    circ.rz(x[0], 0)
    idx = 1
    for iN  in range(N):
        for _ in range(M):
            circ.i(0)
            circ.rz(x[idx],0)
            idx += 1
        circ.x(0)
        circ.rz(x[idx],0)
        idx += 1
        for _ in range(2*M):
            circ.i(0)
            circ.rz(x[idx],0)
            idx += 1
        circ.x(0)
        circ.rz(x[idx],0)
        idx += 1
        for _ in range(M):
            circ.i(0)
            circ.rz(x[idx],0)
            idx += 1
    circ.rx(-np.pi/2, 0)
    circ.rz(x[idx],0)
    circ.measure(0,0)
    return circ, x

# %% [markdown]
# The probe signal PSD described above is used to create signal trajectories. Those trajectories will define the $z$-dephasing angles of rotation in the noisy circuit above.

# %%
def schwarma_trajectories(a, b, num_gates, num_trajectories):
    # a: coefficients of linear filter numerator
    # b: coefficients of linear filter demoninator
    # num_gates: number of gates in circuit to be "schwarmafied"
    # num_trajectories: number of noise trajectories required
    traj_list = []
    for _ in range(num_trajectories):
        angles = si.lfilter(b, a, np.random.randn(num_gates + 1000))[1000:]
        traj_list.append(angles)
    return traj_list

# %% [markdown]
# Here is an example of the noisy circuit prior to setting a signal trajectory.

# %%
N, M = 1,1
num_gates = N*(2 + 4*M) + 2
noisy_exp, param_vec = noisy_cpmg_experiment(N, M)
noisy_exp.draw('mpl')

# %% [markdown]
# Now, we construct a set of 10 trajectories and plot the circuit for the first one only.

# %%
noise_traj_list = schwarma_trajectories(a, b, num_gates, 10)

# %%
bound_params = {param_vec[i]: noise_traj_list[0][i] for i in range(num_gates)}
bound_circ = noisy_exp.bind_parameters(bound_params)
bound_circ.draw('mpl')

# %% [markdown]
# ## Filter Spectroscopy Experiment

# %% [markdown]
# Let's now run a filter spectroscopy experiment on CPMG using the QASM simulator.

# %%
def generate_noise_params(s_pow, w0):
    a = [1,]
    NN = 512
    BW = 0.005 # changes narrowness of noise spectrum
    b = si.firwin(NN, BW)*np.cos(w0*np.pi*np.arange(NN))
    b = b/la.norm(b)*np.sqrt(s_pow)
    return a, b

# %%
backend = Aer.get_backend('qasm_simulator')

# %%
N, M = 4, 4
num_gates = N*(2 + 4*M) + 2
noisy_exp, param_vec = noisy_cpmg_experiment(N, M)

# %% [markdown]
# We will set the number of noise/signal trajectories and the number of center frequency steps. In the case of the former, more trajectories will improve the variance of survival probabilities; however, 25-50 is typically enough to get reasonable results, even on hardware. The latter is really just dependent upon the resolution one desires.

# %%
shots = 1000
num_noise_trajs = 30
num_center_freqs = 100
noise_power = 1e-3


all_probs = np.zeros([num_center_freqs, 2])
for center_idx, center in enumerate(np.linspace(0.02, 0.98, num_center_freqs)): # vary noise center frequency
    print('Probing Filter Function at Normalized Frequency: ', center)
    # Generate noise trajectories
    a, b = generate_noise_params(noise_power, center)
    noise_traj_list = schwarma_trajectories(a, b, num_gates, num_noise_trajs)
    
    # Build noisy circuit dictionary
    circ_batch = []
    for traj in noise_traj_list:
        bound_params = {param_vec: traj}
        bound_circ = noisy_exp.bind_parameters(bound_params)
        circ_batch.append(bound_circ)
    
    # Run circuits
    job = qk.execute(circ_batch, backend=backend, optimization_level=0, shots=shots)
    results = job.result()
    
    # Compile Results
    prob = 0
    for circ in circ_batch:
        zero_counts = results.get_counts(circ).get('0',0)
        prob += zero_counts/shots
    prob = prob/num_noise_trajs
    
    all_probs[center_idx, :] = center, prob
# Out:
# Probing Filter Function at Normalized Frequency:  0.02
# Probing Filter Function at Normalized Frequency:  0.029696969696969697
# Probing Filter Function at Normalized Frequency:  0.0393939393939394
# Probing Filter Function at Normalized Frequency:  0.04909090909090909
# Probing Filter Function at Normalized Frequency:  0.05878787878787879
# Probing Filter Function at Normalized Frequency:  0.06848484848484848
# Probing Filter Function at Normalized Frequency:  0.07818181818181819
# Probing Filter Function at Normalized Frequency:  0.08787878787878788
# Probing Filter Function at Normalized Frequency:  0.09757575757575758
# Probing Filter Function at Normalized Frequency:  0.10727272727272728
# Probing Filter Function at Normalized Frequency:  0.11696969696969697
# Probing Filter Function at Normalized Frequency:  0.12666666666666665
# Probing Filter Function at Normalized Frequency:  0.13636363636363635
# Probing Filter Function at Normalized Frequency:  0.14606060606060606
# Probing Filter Function at Normalized Frequency:  0.15575757575757573
# Probing Filter Function at Normalized Frequency:  0.16545454545454544
# Probing Filter Function at Normalized Frequency:  0.17515151515151514
# Probing Filter Function at Normalized Frequency:  0.18484848484848485
# Probing Filter Function at Normalized Frequency:  0.19454545454545455
# Probing Filter Function at Normalized Frequency:  0.20424242424242423
# Probing Filter Function at Normalized Frequency:  0.21393939393939393
# Probing Filter Function at Normalized Frequency:  0.22363636363636363
# Probing Filter Function at Normalized Frequency:  0.2333333333333333
# Probing Filter Function at Normalized Frequency:  0.243030303030303
# Probing Filter Function at Normalized Frequency:  0.25272727272727274
# Probing Filter Function at Normalized Frequency:  0.26242424242424245
# Probing Filter Function at Normalized Frequency:  0.27212121212121215
# Probing Filter Function at Normalized Frequency:  0.28181818181818186
# Probing Filter Function at Normalized Frequency:  0.2915151515151515
# Probing Filter Function at Normalized Frequency:  0.3012121212121212
# Probing Filter Function at Normalized Frequency:  0.3109090909090909
# Probing Filter Function at Normalized Frequency:  0.3206060606060606
# Probing Filter Function at Normalized Frequency:  0.3303030303030303
# Probing Filter Function at Normalized Frequency:  0.34
# Probing Filter Function at Normalized Frequency:  0.34969696969696973
# Probing Filter Function at Normalized Frequency:  0.35939393939393943
# Probing Filter Function at Normalized Frequency:  0.36909090909090914
# Probing Filter Function at Normalized Frequency:  0.3787878787878788
# Probing Filter Function at Normalized Frequency:  0.3884848484848485
# Probing Filter Function at Normalized Frequency:  0.3981818181818182
# Probing Filter Function at Normalized Frequency:  0.4078787878787879
# Probing Filter Function at Normalized Frequency:  0.4175757575757576
# Probing Filter Function at Normalized Frequency:  0.4272727272727273
# Probing Filter Function at Normalized Frequency:  0.436969696969697
# Probing Filter Function at Normalized Frequency:  0.44666666666666666
# Probing Filter Function at Normalized Frequency:  0.45636363636363636
# Probing Filter Function at Normalized Frequency:  0.46606060606060606
# Probing Filter Function at Normalized Frequency:  0.47575757575757577
# Probing Filter Function at Normalized Frequency:  0.48545454545454547
# Probing Filter Function at Normalized Frequency:  0.4951515151515152
# Probing Filter Function at Normalized Frequency:  0.5048484848484849
# Probing Filter Function at Normalized Frequency:  0.5145454545454545
# Probing Filter Function at Normalized Frequency:  0.5242424242424243
# Probing Filter Function at Normalized Frequency:  0.5339393939393939
# Probing Filter Function at Normalized Frequency:  0.5436363636363637
# Probing Filter Function at Normalized Frequency:  0.5533333333333333
# Probing Filter Function at Normalized Frequency:  0.563030303030303
# Probing Filter Function at Normalized Frequency:  0.5727272727272728
# Probing Filter Function at Normalized Frequency:  0.5824242424242424
# Probing Filter Function at Normalized Frequency:  0.5921212121212122
# Probing Filter Function at Normalized Frequency:  0.6018181818181818
# Probing Filter Function at Normalized Frequency:  0.6115151515151516
# Probing Filter Function at Normalized Frequency:  0.6212121212121212
# Probing Filter Function at Normalized Frequency:  0.630909090909091
# Probing Filter Function at Normalized Frequency:  0.6406060606060606
# Probing Filter Function at Normalized Frequency:  0.6503030303030303
# Probing Filter Function at Normalized Frequency:  0.66
# Probing Filter Function at Normalized Frequency:  0.6696969696969697
# Probing Filter Function at Normalized Frequency:  0.6793939393939394
# Probing Filter Function at Normalized Frequency:  0.6890909090909091
# Probing Filter Function at Normalized Frequency:  0.6987878787878788
# Probing Filter Function at Normalized Frequency:  0.7084848484848485
# Probing Filter Function at Normalized Frequency:  0.7181818181818183
# Probing Filter Function at Normalized Frequency:  0.7278787878787879
# Probing Filter Function at Normalized Frequency:  0.7375757575757576
# Probing Filter Function at Normalized Frequency:  0.7472727272727273
# Probing Filter Function at Normalized Frequency:  0.756969696969697
# Probing Filter Function at Normalized Frequency:  0.7666666666666667
# Probing Filter Function at Normalized Frequency:  0.7763636363636364
# Probing Filter Function at Normalized Frequency:  0.7860606060606061
# Probing Filter Function at Normalized Frequency:  0.7957575757575758
# Probing Filter Function at Normalized Frequency:  0.8054545454545454
# Probing Filter Function at Normalized Frequency:  0.8151515151515152
# Probing Filter Function at Normalized Frequency:  0.8248484848484848
# Probing Filter Function at Normalized Frequency:  0.8345454545454546
# Probing Filter Function at Normalized Frequency:  0.8442424242424242
# Probing Filter Function at Normalized Frequency:  0.853939393939394
# Probing Filter Function at Normalized Frequency:  0.8636363636363636
# Probing Filter Function at Normalized Frequency:  0.8733333333333333
# Probing Filter Function at Normalized Frequency:  0.883030303030303
# Probing Filter Function at Normalized Frequency:  0.8927272727272727
# Probing Filter Function at Normalized Frequency:  0.9024242424242425
# Probing Filter Function at Normalized Frequency:  0.9121212121212121
# Probing Filter Function at Normalized Frequency:  0.9218181818181819
# Probing Filter Function at Normalized Frequency:  0.9315151515151515
# Probing Filter Function at Normalized Frequency:  0.9412121212121213
# Probing Filter Function at Normalized Frequency:  0.9509090909090909
# Probing Filter Function at Normalized Frequency:  0.9606060606060606
# Probing Filter Function at Normalized Frequency:  0.9703030303030303
# Probing Filter Function at Normalized Frequency:  0.98

# %% [markdown]
# Below, we plot the survival probability as a function of signal center frequency. The locations where the survival probability drops dramatically corresponds to frequency regimes where the filter function is very large. As expected from CPMG, we find a large fundamental peak, followed by additional, decaying harmonics at higher frequencies. One can compare this result from the snippet from [Dynamical decoupling sequence construction as a filter-design problem
# ](https://arxiv.org/abs/1012.4262) shown below the plot.

# %%
fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax.plot(all_probs[:,0], all_probs[:,1])
ax.set_ylabel('Survival Probability')
ax.set_xlabel('Center Frequency')
# Out:
# Text(0.5, 0, 'Center Frequency')

# %% [markdown]
# ![image.png](attachment:12d868c1-10e1-45c9-a6b5-35e48a330ecd.png)
